# %%
#using our previous real estate data 

import pandas as pd 
import matplotlib.pyplot as plt

ct_re_2 = pd.read_csv("Real_Estate_Sales_2001-2020_GL.csv", low_memory=False)
ct_re_2
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
df = ct_re_2.groupby("Property Type")[["Sale Amount"]].mean().round()
df
# Out:
#                 Sale Amount
# Property Type
# Apartments       12834307.0
# Commercial        1788884.0
# Condo              260211.0
# Four Family        314291.0
# Industrial        2004287.0
# Public Utility     369709.0
# Residential        479356.0
# Single Family      388514.0
# Three Family       179845.0
# Two Family         199045.0
# Vacant Land        295702.0

# %%
#see all the colors you can choose from at
#https://matplotlib.org/stable/gallery/color/named_colors.html#sphx-glr-gallery-color-named-colors-py


colors = ["orchid", "navy", "limegreen", "coral", "slategray", "pink", "black", "teal", "indigo",
          "cyan", "gold"]

ax = df.plot(kind = "pie", y="Sale Amount", title="Types of Homes Sold",
            ylabel = "", figsize=(10,10), radius=1, startangle=50, labeldistance=1.05,
            colors=colors)
ax.legend(bbox_to_anchor=(.0, .5))

plt.show()

# %%
#let's use a new data set 

file_name= "Broome_County_Annual_Employee_Earnings__Beginning_2009.csv"

broome_data = pd.read_csv(f"{file_name}")
broome_data #this variable stores the data frame
# Out:
#        Earnings Year                     Department      Employee Name  \
# 0               2021                    Arena-Admin    Antalek,Karen K
# 1               2021                    Arena-Admin  Aurelio,Jessica A
# 2               2021                    Arena-Admin   Aurelio,Joseph J
# 3               2021                    Arena-Admin     Beach,Eugene A
# 4               2021                    Arena-Admin     Bezek,Judith A
# ...              ...                            ...                ...
# 34775           2009         WPNH - Social Services     Zapata,Janet E
# 34776           2009      WPNH - Volunteer Programs  Broderick,Debra M
# 34777           2009  Youth Bureau - Administration      Foley,Karen M
# 34778           2009  Youth Bureau - Administration     Roberts,Beth A
# 34779           2009          Youth Bureau - Grants      Guth,Pamela J
#
#                     Position Title                      Union Name  \
# ...

# %%
#we can plot the dataframe with no other arguments, 
#but it doesn't turn out very nicely, does it?

broome_data.plot()
plt.show()

# %%
#example of customizing a graph
#ax refers to Axes, that is an object from matplotlib

#taking two columns that it makes sense to graph together


ax = broome_data.plot(kind="hist", x="Earnings Year", y="Total Earnings", xlim=(0, 150000), 
                title="Total Earnings Broome County Employees, 2009-2021",
                 figsize = (10,10), fontsize=10, color="Green", legend=False)

ax.set_xlabel("Salary")
ax.set_ylabel("Number of employees")
plt.show()

# %%
#we can use value_counts() to count the data in a column to plot it
#https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html

counted = full_part.value_counts()
colors = ["Orange", "Pink"]
ax = counted.plot(kind="pie", legend=True, title="Broome County Workers 2009-2021",
             ylabel = "", labeldistance=None, autopct='%1.1f%%',
            colors = colors, shadow=True, explode=[.05, .05])

ax.legend(["Full Time", "Part Time"], bbox_to_anchor=(.9, .24))
#can also use loc="" to tie to a specific location

plt.show()
